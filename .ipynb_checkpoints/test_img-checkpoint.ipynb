# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./vk.jpg')
img.shape
# Out:
# (865, 654, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (865, 654)

# %%
gray
# Out:
# array([[214, 214, 215, ..., 124, 126, 135],
#        [214, 214, 215, ..., 127, 128, 135],
#        [214, 214, 215, ..., 129, 130, 133],
#        ...,
#        [ 53,  53,  53, ..., 162, 171, 197],
#        [ 51,  52,  52, ..., 168, 170, 195],
#        [ 52,  51,  51, ..., 153, 151, 155]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')
